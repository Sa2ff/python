# %%
#csv
#pandas

# %%
try:
    file=open('datas.csv','x')
    file.close()
except:
    print('the file is already there.')
# Out:
# the file is already there.

# %%
import pandas as pd 
df=pd.read_csv('datas.csv')
df
# Out:
#    sn    name  age      add      phone
# 0   1     ram   34      ktm  986434567
# 1   2   shyam   33     pokh      98760
# 2   3    gita   44    dhang       9876
# 3   4   kashi   12  bajhang       9808
# 4   5  lokesh   67   bajura      98765
# 5   6    mala   99      ktm     976659

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(1)
# Out:
#    sn name  age  add      phone
# 0   1  ram   34  ktm  986434567

# %%
df.tail(3)
# Out:
#    sn    name  age      add   phone
# 3   4   kashi   12  bajhang    9808
# 4   5  lokesh   67   bajura   98765
# 5   6    mala   99      ktm  976659

# %%
df=pd.read_csv('datas.csv',index_col='sn')
df
# Out:
#       name  age      add      phone
# sn
# 1      ram   34      ktm  986434567
# 2    shyam   33     pokh      98760
# 3     gita   44    dhang       9876
# 4    kashi   12  bajhang       9808
# 5   lokesh   67   bajura      98765
# 6     mala   99      ktm     976659

# %%
df
# Out:
#       name  age      add      phone
# sn
# 1      ram   34      ktm  986434567
# 2    shyam   33     pokh      98760
# 3     gita   44    dhang       9876
# 4    kashi   12  bajhang       9808
# 5   lokesh   67   bajura      98765
# 6     mala   99      ktm     976659

# %%
#loc and iloc
df.iloc[0:4]
# Out:
#      name  age      add      phone
# sn
# 1     ram   34      ktm  986434567
# 2   shyam   33     pokh      98760
# 3    gita   44    dhang       9876
# 4   kashi   12  bajhang       9808

# %%
df
# Out:
#    sn    name  age      add      phone
# 0   1     ram   34      ktm  986434567
# 1   2   shyam   33     pokh      98760
# 2   3    gita   44    dhang       9876
# 3   4   kashi   12  bajhang       9808
# 4   5  lokesh   67   bajura      98765
# 5   6    mala   99      ktm     976659

# %%
df.loc[2:5]
# Out:
#       name  age      add  phone
# sn
# 2    shyam   33     pokh  98760
# 3     gita   44    dhang   9876
# 4    kashi   12  bajhang   9808
# 5   lokesh   67   bajura  98765

# %%
df['name']
# Out:
# 0       ram
# 1     shyam
# 2      gita
# 3     kashi
# 4    lokesh
# 5      mala
# Name: name, dtype: object

# %%
df['name']=='mala'
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# Name: name, dtype: bool

# %%
data=df[(df['name']=='ram')| (df['age']>50)]

# %%
df
# Out:
#       name  age      add      phone
# sn
# 1      ram   34      ktm  986434567
# 2    shyam   33     pokh      98760
# 3     gita   44    dhang       9876
# 4    kashi   12  bajhang       9808
# 5   lokesh   67   bajura      98765
# 6     mala   99      ktm     976659

# %%
data=df[(df['name']=='ram')| (df['age']>50)]

# %%
data.to_csv('data2.csv')

# %%
import pandas as pd 
df=pd.read_csv('datas.csv')
df
# Out:
#    sn    name  age      add      phone
# 0   1     ram   34      ktm  986434567
# 1   2   shyam   33     pokh      98760
# 2   3    gita   44    dhang       9876
# 3   4   kashi   12  bajhang       9808
# 4   5  lokesh   67   bajura      98765
# 5   6    mala   99      ktm     976659

# %%
data={'name':['sita','gita','rita'],
     'age':[23,45,6],
    'address':['ktm','dang','pokh']}
df=pd.DataFrame(data)
df
# Out:
#    name  age address
# 0  sita   23     ktm
# 1  gita   45    dang
# 2  rita    6    pokh
